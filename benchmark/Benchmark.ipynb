# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

matplotlib.rcParams['figure.figsize'] = (14,10)

# %%
data = [[[278, 1056, 8], [118, 866, 8], [119, 913, 9]], [[368, 2359, 8], [92, 1000, 8], [38, 488, 9]], [[75, 778, 14], [45, 513, 14], [49, 527, 15]], [[25, 319, 9], [17, 265, 9], [15, 254, 9]], [[310, 2071, 9], [128, 1250, 9], [86, 773, 10]], [[227, 1643, 9], [104, 1003, 9], [57, 717, 10]], [[585, 4642, 13], [262, 2160, 13], [261, 2120, 13]], [[196, 949, 12], [129, 915, 12], [83, 772, 13]], [[83, 683, 12], [48, 461, 12], [37, 421, 12]], [[260, 1829, 17], [229, 1564, 17], [214, 1461, 17]], [[106, 815, 25], [73, 740, 27], [80, 769, 29]], [[130, 1278, 17], [70, 728, 17], [63, 597, 17]], [[1287, 8040, 16], [748, 5314, 17], [536, 3809, 16]], [[1181, 8107, 17], [618, 4503, 17], [745, 5566, 18]], [[72, 525, 23], [73, 522, 23], [73, 523, 23]], [[322, 2525, 21], [265, 1984, 21], [282, 2135, 22]], [[309, 2109, 24], [276, 1966, 24], [202, 1639, 26]], [[189, 1583, 25], [145, 1413, 25], [167, 1545, 25]], [[50, 484, 22], [49, 472, 22], [49, 471, 22]], [[134, 1372, 10], [47, 617, 10], [57, 745, 10]], [[23, 258, 21], [22, 250, 21], [23, 252, 21]], [[557, 3853, 26], [374, 2857, 26], [370, 2876, 27]], [[325, 2444, 29], [164, 1447, 29], [184, 1596, 31]], [[616, 4242, 25], [601, 4135, 25], [604, 4113, 26]], [[1478, 8476, 27], [1169, 6875, 27], [1053, 6268, 27]], [[725, 4760, 28], [604, 3899, 28], [578, 3748, 29]], [[319, 2582, 28], [299, 2367, 28], [289, 2295, 29]], [[270, 1991, 30], [209, 1623, 30], [165, 1448, 30]], [[671, 4316, 31], [681, 4293, 32], [699, 4299, 34]], [[143, 1170, 32], [127, 1095, 32], [126, 1062, 33]], [[555, 3875, 37], [532, 3749, 37], [537, 3662, 37]], [[65, 562, 37], [58, 517, 37], [58, 495, 37]], [[613, 4034, 40], [433, 3125, 41], [313, 2293, 41]], [[657, 4370, 43], [630, 4264, 44], [574, 3852, 45]], [[553, 3951, 43], [551, 3822, 45], [559, 3793, 44]], [[357, 2618, 44], [296, 2136, 44], [293, 2110, 44]], [[293, 1944, 47], [276, 1904, 47], [238, 1767, 47]], [[488, 3651, 48], [438, 3239, 49], [454, 3266, 50]], [[503, 3587, 50], [501, 3536, 51], [505, 3510, 52]], [[447, 3056, 51], [401, 2796, 51], [383, 2714, 51]]]
data = np.array(data)

# %%
plt.plot(range(1,41), data[:,0,0]/100, label="Trivial")
plt.plot(range(1,41), data[:,1,0]/100, label="BlockingCars")
plt.plot(range(1,41), data[:,2,0]/100, label="AdvancedBlocking")
plt.legend()

# %%
aggreg = data.sum(axis=0)[:,:2]

# %%
aggreg/40
# Out:
# array([[  396.125,  2722.675],
#        [  297.55 ,  2154.625],
#        [  280.45 ,  2041.6  ]])

# %%
aggreg/aggreg[0]*100
# Out:
# array([[ 100.        ,  100.        ],
#        [  75.11517829,   79.13632733],
#        [  70.7983591 ,   74.98507901]])
